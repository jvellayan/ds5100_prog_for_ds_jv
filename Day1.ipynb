# %%
import pandas as pd

demo = pd.read_csv('archive_2/demographic.csv')
diet = pd.read_csv('archive_2/diet.csv')
exam = pd.read_csv('archive_2/examination.csv')
labs = pd.read_csv('archive_2/labs.csv')
questions = pd.read_csv('archive_2/questionnaire.csv')
meds = pd.read_csv('archive_2/medications.csv',encoding= 'unicode_escape')

# %%
questions
# Out:
#         SEQN  ACD011A  ACD011B  ACD011C  ACD040  ACD110  ALQ101  ALQ110  \
# 0      73557      1.0      NaN      NaN     NaN     NaN     1.0     NaN
# 1      73558      1.0      NaN      NaN     NaN     NaN     1.0     NaN
# 2      73559      1.0      NaN      NaN     NaN     NaN     1.0     NaN
# 3      73560      1.0      NaN      NaN     NaN     NaN     NaN     NaN
# 4      73561      1.0      NaN      NaN     NaN     NaN     1.0     NaN
# ...      ...      ...      ...      ...     ...     ...     ...     ...
# 10170  83727      NaN      NaN      NaN     3.0     NaN     1.0     NaN
# 10171  83728      NaN      NaN      NaN     NaN     NaN     NaN     NaN
# 10172  83729      1.0      NaN      NaN     NaN     NaN     NaN     NaN
# 10173  83730      NaN      NaN      NaN     4.0     NaN     NaN     NaN
# 10174  83731      NaN      NaN      NaN     NaN     5.0     NaN     NaN
#
#        ALQ120Q  ALQ120U  ...  WHD080U  WHD080L  WHD110  WHD120  WHD130  \
# ...

# %%
demo
# Out:
#         SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDAGEMN  RIDRETH1  \
# 0      73557         8         2         1        69       NaN         4
# 1      73558         8         2         1        54       NaN         3
# 2      73559         8         2         1        72       NaN         3
# 3      73560         8         2         1         9       NaN         3
# 4      73561         8         2         2        73       NaN         3
# ...      ...       ...       ...       ...       ...       ...       ...
# 10170  83727         8         2         1        26       NaN         2
# 10171  83728         8         2         2         2      24.0         1
# 10172  83729         8         2         2        42       NaN         4
# 10173  83730         8         2         1         7       NaN         2
# 10174  83731         8         2         1        11       NaN         5
#
#        RIDRETH3  RIDEXMON  RIDEXAGM  ...  DMDHREDU  DMDHRMAR  DMDHSEDU  \
# ...

# %%
diet
# Out:
#        SEQN         WTDRD1         WTDR2D  DR1DRSTZ  DR1EXMER  DRABF  DRDINT  \
# 0     73557   16888.327864   12930.890649         1      49.0    2.0     2.0
# 1     73558   17932.143865   12684.148869         1      59.0    2.0     2.0
# 2     73559   59641.812930   39394.236709         1      49.0    2.0     2.0
# 3     73560  142203.069917  125966.366442         1      54.0    2.0     2.0
# 4     73561   59052.357033   39004.892993         1      63.0    2.0     2.0
# ...     ...            ...            ...       ...       ...    ...     ...
# 9808  83727   14146.781331   10520.302070         1      59.0    2.0     2.0
# 9809  83728   38750.761193   51815.103262         1      25.0    2.0     2.0
# 9810  83729   15272.505199   10401.781170         1      59.0    2.0     2.0
# 9811  83730       0.000000            NaN         5       NaN    NaN     NaN
# 9812  83731    5805.674812    4339.132077         1      49.0    2.0     2.0
#
# ...

# %%
exam
# Out:
#        SEQN  PEASCST1  PEASCTM1  PEASCCT1  BPXCHR  BPAARM  BPACSZ  BPXPLS  \
# 0     73557         1     620.0       NaN     NaN     1.0     4.0    86.0
# 1     73558         1     766.0       NaN     NaN     1.0     4.0    74.0
# 2     73559         1     665.0       NaN     NaN     1.0     4.0    68.0
# 3     73560         1     803.0       NaN     NaN     1.0     2.0    64.0
# 4     73561         1     949.0       NaN     NaN     1.0     3.0    92.0
# ...     ...       ...       ...       ...     ...     ...     ...     ...
# 9808  83727         1     611.0       NaN     NaN     1.0     3.0    60.0
# 9809  83728         1     124.0       NaN   110.0     NaN     NaN     NaN
# 9810  83729         1     679.0       NaN     NaN     1.0     4.0    80.0
# 9811  83730         1     381.0       NaN    72.0     NaN     NaN     NaN
# 9812  83731         1     498.0       NaN     NaN     1.0     3.0    90.0
#
#       BPXPULS  BPXPTY  ...  CSXLEAOD  CSXSOAOD  CSXGRAOD  CSXONOD  CSXNGSOD  \
# ...

# %%
labs
# Out:
#        SEQN  URXUMA  URXUMS  URXUCR.x   URXCRS  URDACT     WTSAF2YR.x  LBXAPB  \
# 0     73557     4.3     4.3      39.0   3447.6   11.03            NaN     NaN
# 1     73558   153.0   153.0      50.0   4420.0  306.00            NaN     NaN
# 2     73559    11.9    11.9     113.0   9989.2   10.53  142196.890197    57.0
# 3     73560    16.0    16.0      76.0   6718.4   21.05            NaN     NaN
# 4     73561   255.0   255.0     147.0  12994.8  173.47  142266.006548    92.0
# ...     ...     ...     ...       ...      ...     ...            ...     ...
# 9808  83727     1.9     1.9      47.0   4154.8    4.04   67775.162806    88.0
# 9809  83728     NaN     NaN       NaN      NaN     NaN            NaN     NaN
# 9810  83729     6.0     6.0     117.0  10342.8    5.13            NaN     NaN
# 9811  83730     4.5     4.5      86.0   7602.4    5.23            NaN     NaN
# 9812  83731     5.3     5.3     114.0  10077.6    4.65            NaN     NaN
#
# ...

# %%
meds
# Out:
#         SEQN  RXDUSE           RXDDRUG RXDDRGID  RXQSEEN  RXDDAYS RXDRSC1  \
# 0      73557       1             99999      NaN      NaN      NaN     NaN
# 1      73557       1           INSULIN   d00262      2.0   1460.0     E11
# 2      73558       1        GABAPENTIN   d03182      1.0    243.0  G25.81
# 3      73558       1  INSULIN GLARGINE   d04538      1.0    365.0     E11
# 4      73558       1        OLMESARTAN   d04801      1.0     14.0   E11.2
# ...      ...     ...               ...      ...      ...      ...     ...
# 20189  83727       2               NaN      NaN      NaN      NaN     NaN
# 20190  83728       2               NaN      NaN      NaN      NaN     NaN
# 20191  83729       2               NaN      NaN      NaN      NaN     NaN
# 20192  83730       2               NaN      NaN      NaN      NaN     NaN
# 20193  83731       2               NaN      NaN      NaN      NaN     NaN
#
#       RXDRSC2 RXDRSC3                                            RXDRSD1  \
# ...

# %% [markdown]
# Imported needed packages

# %%
import pandas as pd
import numpy as np
import os
import sys

# %%
my_path = os.chdir('/Users/colinobrien/Desktop/Repo/DS_5100/ds5100_prog_for_ds_jv')
COVID_data = pd.read_excel('MortalityDataWHR2021C2.xlsx')

cols_to_remove = ['Excess deaths in 2020 per 100,000 population, relative to 2017-2019 average','All-cause death count, 2020','All-cause death count, 2019','All-cause death count, 2018','All-cause death count, 2017','Log of average distance to SARS countries']
removed_cols = COVID_data[cols_to_remove]

COVID_data_cleaned = COVID_data.drop(cols_to_remove, axis=1)
pd.options.display.float_format = '{:.3f}'.format 
COVID_data_cleaned
# Out:
#           Country name  Population 2020  Population 2019  \
# 0        United States    331002647.000    328239523.000
# 1                Egypt    102334403.000    100388073.000
# 2              Morocco     36910558.000     36471769.000
# 3              Lebanon      6825442.000      6855713.000
# 4         Saudi Arabia     34813867.000     34268528.000
# ..                 ...              ...              ...
# 161              Yemen     29825968.000     29161922.000
# 162             Kosovo      1932774.000      1794248.000
# 163  Somaliland region              NaN              NaN
# 164       North Cyprus              NaN              NaN
# 165        South Sudan     11193729.000     11062113.000
#
#      COVID-19 deaths per 100,000 population in 2020  Median age  Island  \
# 0                                           104.451      38.300       0
# 1                                             7.457      25.300       0
# ...

# %% [markdown]
# In this section, I cleaned removed several columns that were not very helpful for our analysis. I also change the decimal place to be set to a max of 3 to make floats easier to see on screen.

# %%
happy19 = COVID_data = pd.read_csv('world-happiness-report-2021.csv')

# %%
happy20 = COVID_data = pd.read_csv('WHR2020.csv')
old_header = list(happy20.columns.values)
new_header = []
for i in old_header:
    i = '20_' + i
    new_header.append(i)
new_header
happy20_cleaned = COVID_data = pd.read_csv('WHR2020.csv', names = new_header, header = None, skiprows=1)
happy20_cleaned=happy20_cleaned.rename(columns = {'20_Country name':'Country name'})
happy20_cleaned
# Out:
#                  Country name 20_Regional indicator  20_Ladder score  \
# 0                     Finland        Western Europe            7.809
# 1                     Denmark        Western Europe            7.646
# 2                 Switzerland        Western Europe            7.560
# 3                     Iceland        Western Europe            7.504
# 4                      Norway        Western Europe            7.488
# ..                        ...                   ...              ...
# 148  Central African Republic    Sub-Saharan Africa            3.476
# 149                    Rwanda    Sub-Saharan Africa            3.312
# 150                  Zimbabwe    Sub-Saharan Africa            3.299
# 151               South Sudan    Sub-Saharan Africa            2.817
# 152               Afghanistan            South Asia            2.567
#
#      20_Standard error of ladder score  20_upperwhisker  20_lowerwhisker  \
# ...

# %%
happy19 = COVID_data = pd.read_csv('world-happiness-report-2021.csv')
old_header2 = list(happy19.columns.values)
new_header2 = []
for i in old_header2:
    i = '19_' + i
    new_header2.append(i)
new_header2
happy19_cleaned = COVID_data = pd.read_csv('WHR2020.csv', names = new_header2, header = None,  skiprows=1)
happy19_cleaned=happy19_cleaned.rename(columns = {'19_Country name':'Country name'})
happy19_cleaned
# Out:
#                  Country name 19_Regional indicator  19_Ladder score  \
# 0                     Finland        Western Europe            7.809
# 1                     Denmark        Western Europe            7.646
# 2                 Switzerland        Western Europe            7.560
# 3                     Iceland        Western Europe            7.504
# 4                      Norway        Western Europe            7.488
# ..                        ...                   ...              ...
# 148  Central African Republic    Sub-Saharan Africa            3.476
# 149                    Rwanda    Sub-Saharan Africa            3.312
# 150                  Zimbabwe    Sub-Saharan Africa            3.299
# 151               South Sudan    Sub-Saharan Africa            2.817
# 152               Afghanistan            South Asia            2.567
#
#      19_Standard error of ladder score  19_upperwhisker  19_lowerwhisker  \
# ...

# %%
# joined = pd.merge(happy19, happy20, on="Country name", how='inner') 
just_20_COVID = pd.merge(happy20, COVID_data_cleaned , on="Country name", how='outer')

# %%
just_20_COVID
# Out:
#           Country name Regional indicator  Ladder score  \
# 0              Finland     Western Europe         7.809
# 1              Denmark     Western Europe         7.646
# 2          Switzerland     Western Europe         7.560
# 3              Iceland     Western Europe         7.504
# 4               Norway     Western Europe         7.488
# ..                 ...                ...           ...
# 163            Somalia                NaN           NaN
# 164              Sudan                NaN           NaN
# 165           Suriname                NaN           NaN
# 166           Eswatini                NaN           NaN
# 167  Somaliland region                NaN           NaN
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.031         7.870         7.748
# 1                             0.033         7.711         7.580
# 2                             0.035         7.629         7.491
# ...

# %%
full_19_20_COVID = pd.merge(just_20_COVID, happy20 , on="Country name", how='outer')

# %%
full_19_20_COVID
# Out:
#           Country name Regional indicator_x  Ladder score_x  \
# 0              Finland       Western Europe           7.809
# 1              Denmark       Western Europe           7.646
# 2          Switzerland       Western Europe           7.560
# 3              Iceland       Western Europe           7.504
# 4               Norway       Western Europe           7.488
# ..                 ...                  ...             ...
# 163            Somalia                  NaN             NaN
# 164              Sudan                  NaN             NaN
# 165           Suriname                  NaN             NaN
# 166           Eswatini                  NaN             NaN
# 167  Somaliland region                  NaN             NaN
#
#      Standard error of ladder score_x  upperwhisker_x  lowerwhisker_x  \
# 0                               0.031           7.870           7.748
# 1                               0.033           7.711           7.580
# ...

# %% [markdown]
# For some reason, when I added the 2019 data into joined2, it messes up the column names. Not sure why but the x is for 2019, and the y is for 2020.

# %%
just_20_COVID.to_csv("Cleaned_just_20_COVID.csv", sep=",")

# %%
full_19_20_COVID.to_csv("full_19_20_COVID.csv", sep=",")
